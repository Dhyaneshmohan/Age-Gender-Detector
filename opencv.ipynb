# %%
import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread("resources/gayatri.png")

# %%
plt.imshow(img)

# %%
img2=cv2.imread("resources/gayatri.png")

# %%
result=img+img2

# %%
plt.imshow(result)

# %%
result=img-img2

# %%
plt.imshow(result)

# %%
result=img*img2

# %%
plt.imshow(result)

# %%
result=img/img2
plt.imshow(result)
# Out:
# C:\Users\dhyanesh mohan\AppData\Local\Temp\ipykernel_12524\461477655.py:1: RuntimeWarning: invalid value encountered in divide
#   result=img/img2

# %%
img1=cv2.imread("resources/IMG_20230129_214436_853.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("blur imge")
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
